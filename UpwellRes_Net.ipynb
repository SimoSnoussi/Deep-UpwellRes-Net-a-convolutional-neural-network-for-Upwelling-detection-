# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoSnoussi/Deep-UpwellRes-Net-a-convolutional-neural-network-for-Upwelling-detection-/blob/master/UpwellRes_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from tqdm import tqdm 

from keras import backend as K 
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, UpSampling2D, Dropout, Reshape, Conv2DTranspose, Add
from keras.layers import BatchNormalization, Activation 
from keras.models import Model, load_model 
from keras.optimizers import Adam 
from IPython.display import SVG 
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint, ReduceLROnPlateau 
from keras.utils import np_utils, plot_model
# Out:
# Using TensorFlow backend.

# %%
sst_path  = '/SST_train.npy'
mask_path = '/MASK_train.npy'

sst_train  = np.load(sst_path)
mask_train = np.load(mask_path)
mask_train = np.nan_to_num(mask_train, nan=1)

index = np.random.randint(sst_train.shape[0])

plt.figure(figsize=(15, 10))
plt.subplot(121)
plt.imshow(sst_train[index,:,:], cmap='jet')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.title('SST');
plt.subplot(122)
plt.imshow(mask_train[index,:,:], cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.title('Ground Truth');

# %%
sst_train = np.nan_to_num(sst_train, nan=1)

### Expand dims 
sst_train = np.expand_dims(sst_train, 3)
mask_train = np.expand_dims(mask_train, 3)

### One-Hot-Encoding 
mask_train_cat = np.reshape(mask_train[:,:,:,0], (1374,192*192))
mask_train_cat = np_utils.to_categorical(mask_train_cat, 2)
print(mask_train_cat.shape)
# Out:
# (1374, 36864, 2)

# %%
def BatchActivation(x): 
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  return x 

def convBlock(x, filters, size, padding='same', activation=True): 
  x = Conv2D(filters, size, padding=padding)(x)
  if activation == True: 
    x = BatchActivation(x)
  return x 

def residualBlock(blockInput, num_filters=16, batch_activation=False): 
  x = BatchActivation(blockInput)
  x = convBlock(x, num_filters, (3,3))
  x = convBlock(x, num_filters, (3,3), activation=False)
  x = Add()([x, blockInput])
  if batch_activation: 
    x = BatchActivation(x)
  return x

# %%
input_size  = (192, 192, 1) 

def get_resunet(input_img, n_filters, DropoutRatio = 0.5, num_classes=2):
    # contracting path
    c1 = Conv2D(n_filters * 1, (3, 3), activation=None, padding="same")(input_img)
    c1 = residualBlock(c1, n_filters * 1)
    c1 = residualBlock(c1, n_filters * 1, True)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(DropoutRatio/2)(p1)

    c2 = Conv2D(n_filters * 2, (3, 3), activation=None, padding="same")(p1)
    c2 = residualBlock(c2, n_filters * 2)
    c2 = residualBlock(c2, n_filters * 2, True)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(DropoutRatio)(p2)

    c3 = Conv2D(n_filters * 4, (3, 3), activation=None, padding="same")(p2)
    c3 = residualBlock(c3, n_filters * 4)
    c3 = residualBlock(c3, n_filters * 4, True)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(DropoutRatio)(p3)

    c4 = Conv2D(n_filters * 8, (3, 3), activation=None, padding="same")(p3)
    c4 = residualBlock(c4, n_filters * 8)
    c4 = residualBlock(c4, n_filters * 8, True)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(DropoutRatio)(p4)
 
    # Bottleneck 
    c5 = Conv2D(n_filters * 16, (3, 3), activation=None, padding="same")(p4)
    c5 = residualBlock(c5,n_filters * 16)
    c5 = residualBlock(c5,n_filters * 16, True)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding="same")(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(DropoutRatio)(u6)
    c6 = Conv2D(n_filters * 8, (3, 3), activation=None, padding="same")(u6)
    c6 = residualBlock(c6,n_filters * 8)
    c6 = residualBlock(c6,n_filters * 8, True)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding="same")(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(DropoutRatio)(u7)
    c7 = Conv2D(n_filters * 4, (3, 3), activation=None, padding="same")(u7)
    c7 = residualBlock(c7,n_filters * 4)
    c7 = residualBlock(c7,n_filters * 4, True)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding="same")(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(DropoutRatio)(u8)
    c8 = Conv2D(n_filters * 2, (3, 3), activation=None, padding="same")(u8)
    c8 = residualBlock(c8,n_filters * 2)
    c8 = residualBlock(c8,n_filters * 2, True)

    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides=(2, 2), padding="same")(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(DropoutRatio)(u9)
    c9 = Conv2D(n_filters * 1, (3, 3), activation=None, padding="same")(u9)
    c9 = residualBlock(c9,n_filters * 1)
    c9 = residualBlock(c9,n_filters * 1, True)
 
    output     = Conv2D(num_classes, (1,1), padding='valid')(c9)
    output     = Reshape((input_size[0]*input_size[1], num_classes))(output)
    output     = Activation('softmax')(output)
    model = Model(inputs=[input_img], outputs=[output])
    return model

# %% [markdown]
# # Calculate Weigths (Data Imbalance)

# %%
unique, counts = np.unique(mask_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 8085897, 1.0: 42565239}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.8403609940752366, 0.15963900592476346]

# %%
epsilon=0.00001  ## small constant add to numerator and denominator to avoid division by zero errors. 

### IoU coefficient 
def iou_class_1(y_true, y_pred):
  y_true_ = y_true[:,:,0]
  y_pred_ = y_pred[:,:,0]
  intersection = K.sum(y_true_ * y_pred_)
  union = (K.sum(y_true_) + K.sum(y_pred_)) - intersection
  iou = (intersection + epsilon) / (union + epsilon)
  return iou

def iou_class_2(y_true, y_pred):
  y_true_ = y_true[:,:,1]
  y_pred_ = y_pred[:,:,1]
  intersection = K.sum(y_true_ * y_pred_)
  union = (K.sum(y_true_) + K.sum(y_pred_)) - intersection
  iou = (intersection + epsilon) / (union + epsilon)
  return iou

def mean_iou(y_true, y_pred): 
  return ((iou_class_1(y_true, y_pred) + iou_class_2(y_true, y_pred)) / 2)


### Dice Coefficient 
def dice_coef_class_1(y_true, y_pred): 
  y_true_ = y_true[:,:,0]
  y_pred_ = y_pred[:,:,0]
  dice_numerator   = 2 * K.sum(y_true_ * y_pred_) + epsilon 
  dice_denominator = K.sum(y_true_) + K.sum(y_pred_) + epsilon 
  dice_coeff       = dice_numerator / dice_denominator 
  return dice_coeff 

def dice_coef_class_2(y_true, y_pred): 
  y_true_ = y_true[:,:,1]
  y_pred_ = y_pred[:,:,1]
  dice_numerator   = 2 * K.sum(y_true_ * y_pred_) + epsilon 
  dice_denominator = K.sum(y_true_) + K.sum(y_pred_) + epsilon 
  dice_coeff       = dice_numerator / dice_denominator
  return dice_coeff 

def dice_coefficient(y_true, y_pred): 
  return ((dice_coef_class_1(y_true, y_pred) + dice_coef_class_2(y_true, y_pred)) / 2) 

### Weighted Dice Loss 
def weighted_dice_coef(y_true, y_pred):
    return (0.84*dice_coef_class_1(y_true, y_pred) + 0.16*dice_coef_class_2(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_dice_coef(y_true, y_pred)

# %%
input_img = Input(input_size)
model = get_resunet(input_img, n_filters=16, DropoutRatio = 0.5, num_classes=2)

model.compile(optimizer=Adam(), loss=dice_coef_loss, metrics=["categorical_accuracy", dice_coefficient, 
                                                              dice_coef_class_1, dice_coef_class_2, mean_iou])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 192, 192, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 192, 192, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 192, 192, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 192, 192, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 192, 192, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 192, 192, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 192, 192, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 192, 192, 16) 0           conv2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 192, 192, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 192, 192, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 192, 192, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 192, 192, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 192, 192, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 192, 192, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 192, 16) 0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 192, 192, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 192, 192, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 96, 96, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 96, 96, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 96, 96, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 96, 96, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 96, 96, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 96, 96, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 96, 96, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 96, 96, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 96, 96, 32)   0           conv2d_8[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 96, 96, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 96, 96, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 96, 96, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 96, 96, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 96, 96, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 96, 96, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 96, 96, 32)   0           conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 96, 96, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 96, 96, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 48, 32)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 48, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 48, 48, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 48, 48, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 48, 48, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 48, 48, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 48, 48, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 48, 48, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 48, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 48, 48, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 48, 48, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 48, 48, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 48, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 48, 48, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 48, 48, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 48, 48, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 48, 48, 64)   0           conv2d_15[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 48, 48, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 48, 48, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 64)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 24, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 24, 24, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 24, 24, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 24, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 24, 24, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 24, 24, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 24, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 24, 24, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 24, 24, 128)  0           conv2d_18[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 24, 24, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 24, 24, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 24, 24, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 24, 24, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 24, 24, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 24, 24, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 24, 24, 128)  0           conv2d_20[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 24, 24, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 24, 24, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 128)  0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 12, 12, 128)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 12, 12, 256)  295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 12, 12, 256)  1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 12, 12, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 12, 12, 256)  590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 12, 12, 256)  1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 12, 12, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 12, 12, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 256)  0           conv2d_23[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 12, 12, 256)  1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 12, 12, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 12, 12, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 12, 12, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 12, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 12, 12, 256)  590080      activation_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 256)  0           conv2d_25[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 12, 12, 256)  1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 12, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 24, 24, 128)  295040      activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 24, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 24, 24, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 24, 24, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 24, 24, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 24, 24, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 24, 24, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 24, 24, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 24, 24, 128)  147584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 24, 24, 128)  0           conv2d_28[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 24, 24, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 24, 24, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 24, 24, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 24, 24, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 24, 24, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 24, 24, 128)  147584      activation_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 24, 24, 128)  0           conv2d_30[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 24, 24, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 24, 24, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 48, 48, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 48, 48, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 48, 48, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 48, 48, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 48, 48, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 48, 48, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 48, 48, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 48, 48, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 48, 48, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 48, 48, 64)   0           conv2d_33[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 48, 48, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 48, 48, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 48, 48, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 48, 48, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 48, 48, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 48, 48, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 48, 48, 64)   0           conv2d_35[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 48, 48, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 48, 48, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 96, 96, 32)   18464       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 96, 96, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 96, 96, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 96, 96, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 96, 96, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 96, 96, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 96, 96, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 96, 96, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 96, 96, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 96, 96, 32)   0           conv2d_38[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 96, 96, 32)   128         add_15[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 96, 96, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 96, 96, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 96, 96, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 96, 96, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 96, 96, 32)   9248        activation_39[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 96, 96, 32)   0           conv2d_40[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 96, 96, 32)   128         add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 96, 96, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 192, 192, 16) 4624        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 192, 192, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 192, 192, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 192, 192, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 192, 192, 16) 64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 192, 192, 16) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 192, 192, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 192, 192, 16) 64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 192, 192, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 192, 192, 16) 2320        activation_42[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 192, 192, 16) 0           conv2d_43[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 192, 192, 16) 64          add_17[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 192, 192, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 192, 192, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 192, 192, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 192, 192, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 192, 192, 16) 2320        activation_44[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 192, 192, 16) 0           conv2d_45[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 192, 192, 16) 64          add_18[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 192, 192, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 192, 192, 2)  34          activation_45[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 36864, 2)     0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 36864, 2)     0           reshape_1[0][0]
# ==================================================================================================
# Total params: 5,119,874
# Trainable params: 5,112,514
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
# from keras.utils import plot_model 
# plot_model(model)

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.0001, verbose=1),
    ModelCheckpoint('/content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(sst_train, mask_train_cat, 
                    batch_size=16, 
                    epochs=50,
                    shuffle=True,
                    verbose=1,  
                    callbacks=callbacks, 
                    validation_split=0.2)
# Out:
# Train on 1099 samples, validate on 275 samples
# Epoch 1/50
# 1099/1099 [==============================] - 55s 50ms/step - loss: 0.5522 - categorical_accuracy: 0.7738 - dice_coefficient: 0.5326 - dice_coef_class_1: 0.4082 - dice_coef_class_2: 0.6571 - mean_iou: 0.3761 - val_loss: 0.6586 - val_categorical_accuracy: 0.4499 - val_dice_coefficient: 0.3629 - val_dice_coef_class_1: 0.3322 - val_dice_coef_class_2: 0.3936 - val_mean_iou: 0.2224
#
# Epoch 00001: val_loss improved from inf to 0.65856, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 2/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.4430 - categorical_accuracy: 0.9124 - dice_coefficient: 0.6549 - dice_coef_class_1: 0.5111 - dice_coef_class_2: 0.7986 - mean_iou: 0.5048 - val_loss: 0.7665 - val_categorical_accuracy: 0.1672 - val_dice_coefficient: 0.1453 - val_dice_coef_class_1: 0.2752 - val_dice_coef_class_2: 0.0154 - val_mean_iou: 0.0838
#
# Epoch 00002: val_loss did not improve from 0.65856
# Epoch 3/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.3471 - categorical_accuracy: 0.9355 - dice_coefficient: 0.7435 - dice_coef_class_1: 0.6106 - dice_coef_class_2: 0.8764 - mean_iou: 0.6104 - val_loss: 0.7634 - val_categorical_accuracy: 0.1754 - val_dice_coefficient: 0.1529 - val_dice_coef_class_1: 0.2767 - val_dice_coef_class_2: 0.0291 - val_mean_iou: 0.0878
#
# Epoch 00003: val_loss did not improve from 0.65856
# Epoch 4/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.2596 - categorical_accuracy: 0.9482 - dice_coefficient: 0.8147 - dice_coef_class_1: 0.7059 - dice_coef_class_2: 0.9235 - mean_iou: 0.7022 - val_loss: 0.4663 - val_categorical_accuracy: 0.7425 - val_dice_coefficient: 0.6314 - val_dice_coef_class_1: 0.5000 - val_dice_coef_class_2: 0.7629 - val_mean_iou: 0.4879
#
# Epoch 00004: val_loss improved from 0.65856 to 0.46634, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 5/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.1948 - categorical_accuracy: 0.9552 - dice_coefficient: 0.8636 - dice_coef_class_1: 0.7779 - dice_coef_class_2: 0.9494 - mean_iou: 0.7704 - val_loss: 0.6890 - val_categorical_accuracy: 0.3236 - val_dice_coefficient: 0.3088 - val_dice_coef_class_1: 0.3154 - val_dice_coef_class_2: 0.3022 - val_mean_iou: 0.1839
#
# Epoch 00005: val_loss did not improve from 0.46634
# Epoch 6/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.1551 - categorical_accuracy: 0.9593 - dice_coefficient: 0.8925 - dice_coef_class_1: 0.8225 - dice_coef_class_2: 0.9624 - mean_iou: 0.8132 - val_loss: 0.3684 - val_categorical_accuracy: 0.8374 - val_dice_coefficient: 0.7335 - val_dice_coef_class_1: 0.5842 - val_dice_coef_class_2: 0.8829 - val_mean_iou: 0.6052
#
# Epoch 00006: val_loss improved from 0.46634 to 0.36845, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 7/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.1321 - categorical_accuracy: 0.9620 - dice_coefficient: 0.9090 - dice_coef_class_1: 0.8488 - dice_coef_class_2: 0.9692 - mean_iou: 0.8390 - val_loss: 0.2931 - val_categorical_accuracy: 0.8530 - val_dice_coefficient: 0.7888 - val_dice_coef_class_1: 0.6798 - val_dice_coef_class_2: 0.8978 - val_mean_iou: 0.6730
#
# Epoch 00007: val_loss improved from 0.36845 to 0.29307, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 8/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.1134 - categorical_accuracy: 0.9660 - dice_coefficient: 0.9220 - dice_coef_class_1: 0.8698 - dice_coef_class_2: 0.9741 - mean_iou: 0.8598 - val_loss: 0.1964 - val_categorical_accuracy: 0.9241 - val_dice_coefficient: 0.8647 - val_dice_coef_class_1: 0.7804 - val_dice_coef_class_2: 0.9489 - val_mean_iou: 0.7739
#
# Epoch 00008: val_loss improved from 0.29307 to 0.19640, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 9/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.1117 - categorical_accuracy: 0.9645 - dice_coefficient: 0.9233 - dice_coef_class_1: 0.8719 - dice_coef_class_2: 0.9748 - mean_iou: 0.8622 - val_loss: 0.1497 - val_categorical_accuracy: 0.9432 - val_dice_coefficient: 0.8976 - val_dice_coef_class_1: 0.8334 - val_dice_coef_class_2: 0.9618 - val_mean_iou: 0.8229
#
# Epoch 00009: val_loss improved from 0.19640 to 0.14972, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 10/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0936 - categorical_accuracy: 0.9699 - dice_coefficient: 0.9358 - dice_coef_class_1: 0.8926 - dice_coef_class_2: 0.9791 - mean_iou: 0.8828 - val_loss: 0.2027 - val_categorical_accuracy: 0.9122 - val_dice_coefficient: 0.8563 - val_dice_coef_class_1: 0.7704 - val_dice_coef_class_2: 0.9422 - val_mean_iou: 0.7594
#
# Epoch 00010: val_loss did not improve from 0.14972
# Epoch 11/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0902 - categorical_accuracy: 0.9703 - dice_coefficient: 0.9382 - dice_coef_class_1: 0.8965 - dice_coef_class_2: 0.9800 - mean_iou: 0.8868 - val_loss: 0.1143 - val_categorical_accuracy: 0.9589 - val_dice_coefficient: 0.9214 - val_dice_coef_class_1: 0.8695 - val_dice_coef_class_2: 0.9734 - val_mean_iou: 0.8591
#
# Epoch 00011: val_loss improved from 0.14972 to 0.11425, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 12/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0882 - categorical_accuracy: 0.9703 - dice_coefficient: 0.9395 - dice_coef_class_1: 0.8987 - dice_coef_class_2: 0.9804 - mean_iou: 0.8890 - val_loss: 0.1236 - val_categorical_accuracy: 0.9528 - val_dice_coefficient: 0.9153 - val_dice_coef_class_1: 0.8611 - val_dice_coef_class_2: 0.9695 - val_mean_iou: 0.8503
#
# Epoch 00012: val_loss did not improve from 0.11425
# Epoch 13/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0897 - categorical_accuracy: 0.9694 - dice_coefficient: 0.9384 - dice_coef_class_1: 0.8966 - dice_coef_class_2: 0.9802 - mean_iou: 0.8872 - val_loss: 0.1430 - val_categorical_accuracy: 0.9505 - val_dice_coefficient: 0.9037 - val_dice_coef_class_1: 0.8375 - val_dice_coef_class_2: 0.9698 - val_mean_iou: 0.8323
#
# Epoch 00013: val_loss did not improve from 0.11425
# Epoch 14/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0808 - categorical_accuracy: 0.9723 - dice_coefficient: 0.9447 - dice_coef_class_1: 0.9072 - dice_coef_class_2: 0.9822 - mean_iou: 0.8978 - val_loss: 0.0811 - val_categorical_accuracy: 0.9719 - val_dice_coefficient: 0.9452 - val_dice_coef_class_1: 0.9083 - val_dice_coef_class_2: 0.9821 - val_mean_iou: 0.8988
#
# Epoch 00014: val_loss improved from 0.11425 to 0.08113, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 15/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0805 - categorical_accuracy: 0.9721 - dice_coefficient: 0.9450 - dice_coef_class_1: 0.9076 - dice_coef_class_2: 0.9823 - mean_iou: 0.8983 - val_loss: 0.1161 - val_categorical_accuracy: 0.9626 - val_dice_coefficient: 0.9221 - val_dice_coef_class_1: 0.8667 - val_dice_coef_class_2: 0.9774 - val_mean_iou: 0.8616
#
# Epoch 00015: val_loss did not improve from 0.08113
# Epoch 16/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0782 - categorical_accuracy: 0.9728 - dice_coefficient: 0.9463 - dice_coef_class_1: 0.9099 - dice_coef_class_2: 0.9828 - mean_iou: 0.9006 - val_loss: 0.0916 - val_categorical_accuracy: 0.9665 - val_dice_coefficient: 0.9382 - val_dice_coef_class_1: 0.8971 - val_dice_coef_class_2: 0.9794 - val_mean_iou: 0.8875
#
# Epoch 00016: val_loss did not improve from 0.08113
# Epoch 17/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0775 - categorical_accuracy: 0.9727 - dice_coefficient: 0.9470 - dice_coef_class_1: 0.9111 - dice_coef_class_2: 0.9829 - mean_iou: 0.9017 - val_loss: 0.0663 - val_categorical_accuracy: 0.9785 - val_dice_coefficient: 0.9557 - val_dice_coef_class_1: 0.9248 - val_dice_coef_class_2: 0.9866 - val_mean_iou: 0.9170
#
# Epoch 00017: val_loss improved from 0.08113 to 0.06629, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 18/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0781 - categorical_accuracy: 0.9724 - dice_coefficient: 0.9466 - dice_coef_class_1: 0.9104 - dice_coef_class_2: 0.9828 - mean_iou: 0.9012 - val_loss: 0.1057 - val_categorical_accuracy: 0.9607 - val_dice_coefficient: 0.9274 - val_dice_coef_class_1: 0.8790 - val_dice_coef_class_2: 0.9758 - val_mean_iou: 0.8692
#
# Epoch 00018: val_loss did not improve from 0.06629
# Epoch 19/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0714 - categorical_accuracy: 0.9748 - dice_coefficient: 0.9512 - dice_coef_class_1: 0.9180 - dice_coef_class_2: 0.9843 - mean_iou: 0.9089 - val_loss: 0.0745 - val_categorical_accuracy: 0.9739 - val_dice_coefficient: 0.9479 - val_dice_coef_class_1: 0.9122 - val_dice_coef_class_2: 0.9836 - val_mean_iou: 0.9036
#
# Epoch 00019: val_loss did not improve from 0.06629
# Epoch 20/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0693 - categorical_accuracy: 0.9755 - dice_coefficient: 0.9526 - dice_coef_class_1: 0.9204 - dice_coef_class_2: 0.9848 - mean_iou: 0.9115 - val_loss: 0.0583 - val_categorical_accuracy: 0.9791 - val_dice_coefficient: 0.9605 - val_dice_coef_class_1: 0.9339 - val_dice_coef_class_2: 0.9871 - val_mean_iou: 0.9254
#
# Epoch 00020: val_loss improved from 0.06629 to 0.05825, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 21/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0708 - categorical_accuracy: 0.9748 - dice_coefficient: 0.9516 - dice_coef_class_1: 0.9187 - dice_coef_class_2: 0.9844 - mean_iou: 0.9096 - val_loss: 0.0814 - val_categorical_accuracy: 0.9733 - val_dice_coefficient: 0.9456 - val_dice_coef_class_1: 0.9072 - val_dice_coef_class_2: 0.9841 - val_mean_iou: 0.8996
#
# Epoch 00021: val_loss did not improve from 0.05825
# Epoch 22/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0722 - categorical_accuracy: 0.9743 - dice_coefficient: 0.9507 - dice_coef_class_1: 0.9171 - dice_coef_class_2: 0.9842 - mean_iou: 0.9081 - val_loss: 0.0885 - val_categorical_accuracy: 0.9702 - val_dice_coefficient: 0.9402 - val_dice_coef_class_1: 0.8982 - val_dice_coef_class_2: 0.9821 - val_mean_iou: 0.8912
#
# Epoch 00022: val_loss did not improve from 0.05825
# Epoch 23/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0679 - categorical_accuracy: 0.9758 - dice_coefficient: 0.9536 - dice_coef_class_1: 0.9221 - dice_coef_class_2: 0.9851 - mean_iou: 0.9133 - val_loss: 0.1571 - val_categorical_accuracy: 0.9320 - val_dice_coefficient: 0.8900 - val_dice_coef_class_1: 0.8223 - val_dice_coef_class_2: 0.9577 - val_mean_iou: 0.8092
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00023: val_loss did not improve from 0.05825
# Epoch 24/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0604 - categorical_accuracy: 0.9784 - dice_coefficient: 0.9587 - dice_coef_class_1: 0.9307 - dice_coef_class_2: 0.9867 - mean_iou: 0.9222 - val_loss: 0.0407 - val_categorical_accuracy: 0.9858 - val_dice_coefficient: 0.9725 - val_dice_coef_class_1: 0.9537 - val_dice_coef_class_2: 0.9912 - val_mean_iou: 0.9471
#
# Epoch 00024: val_loss improved from 0.05825 to 0.04066, saving model to /content/drive/My Drive/Article_2/weigths/model-ResUpwellNet-0.h5
# Epoch 25/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0579 - categorical_accuracy: 0.9794 - dice_coefficient: 0.9604 - dice_coef_class_1: 0.9335 - dice_coef_class_2: 0.9873 - mean_iou: 0.9254 - val_loss: 0.0421 - val_categorical_accuracy: 0.9853 - val_dice_coefficient: 0.9716 - val_dice_coef_class_1: 0.9522 - val_dice_coef_class_2: 0.9910 - val_mean_iou: 0.9456
#
# Epoch 00025: val_loss did not improve from 0.04066
# Epoch 26/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0574 - categorical_accuracy: 0.9795 - dice_coefficient: 0.9607 - dice_coef_class_1: 0.9341 - dice_coef_class_2: 0.9874 - mean_iou: 0.9259 - val_loss: 0.0466 - val_categorical_accuracy: 0.9841 - val_dice_coefficient: 0.9688 - val_dice_coef_class_1: 0.9472 - val_dice_coef_class_2: 0.9904 - val_mean_iou: 0.9405
#
# Epoch 00026: val_loss did not improve from 0.04066
# Epoch 27/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0560 - categorical_accuracy: 0.9802 - dice_coefficient: 0.9617 - dice_coef_class_1: 0.9357 - dice_coef_class_2: 0.9878 - mean_iou: 0.9276 - val_loss: 0.0439 - val_categorical_accuracy: 0.9850 - val_dice_coefficient: 0.9705 - val_dice_coef_class_1: 0.9502 - val_dice_coef_class_2: 0.9908 - val_mean_iou: 0.9436
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00027: val_loss did not improve from 0.04066
# Epoch 28/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0568 - categorical_accuracy: 0.9797 - dice_coefficient: 0.9611 - dice_coef_class_1: 0.9347 - dice_coef_class_2: 0.9875 - mean_iou: 0.9264 - val_loss: 0.0497 - val_categorical_accuracy: 0.9833 - val_dice_coefficient: 0.9668 - val_dice_coef_class_1: 0.9437 - val_dice_coef_class_2: 0.9899 - val_mean_iou: 0.9370
#
# Epoch 00028: val_loss did not improve from 0.04066
# Epoch 29/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0538 - categorical_accuracy: 0.9809 - dice_coefficient: 0.9632 - dice_coef_class_1: 0.9382 - dice_coef_class_2: 0.9882 - mean_iou: 0.9303 - val_loss: 0.0545 - val_categorical_accuracy: 0.9818 - val_dice_coefficient: 0.9636 - val_dice_coef_class_1: 0.9381 - val_dice_coef_class_2: 0.9891 - val_mean_iou: 0.9313
#
# Epoch 00029: val_loss did not improve from 0.04066
# Epoch 30/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0548 - categorical_accuracy: 0.9805 - dice_coefficient: 0.9625 - dice_coef_class_1: 0.9370 - dice_coef_class_2: 0.9880 - mean_iou: 0.9290 - val_loss: 0.0459 - val_categorical_accuracy: 0.9843 - val_dice_coefficient: 0.9692 - val_dice_coef_class_1: 0.9479 - val_dice_coef_class_2: 0.9905 - val_mean_iou: 0.9412
#
# Epoch 00030: val_loss did not improve from 0.04066
# Epoch 31/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0549 - categorical_accuracy: 0.9804 - dice_coefficient: 0.9624 - dice_coef_class_1: 0.9368 - dice_coef_class_2: 0.9879 - mean_iou: 0.9288 - val_loss: 0.0504 - val_categorical_accuracy: 0.9829 - val_dice_coefficient: 0.9664 - val_dice_coef_class_1: 0.9431 - val_dice_coef_class_2: 0.9898 - val_mean_iou: 0.9363
#
# Epoch 00031: val_loss did not improve from 0.04066
# Epoch 32/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0540 - categorical_accuracy: 0.9808 - dice_coefficient: 0.9630 - dice_coef_class_1: 0.9379 - dice_coef_class_2: 0.9881 - mean_iou: 0.9299 - val_loss: 0.0542 - val_categorical_accuracy: 0.9819 - val_dice_coefficient: 0.9640 - val_dice_coef_class_1: 0.9389 - val_dice_coef_class_2: 0.9892 - val_mean_iou: 0.9323
#
# Epoch 00032: val_loss did not improve from 0.04066
# Epoch 33/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0558 - categorical_accuracy: 0.9801 - dice_coefficient: 0.9618 - dice_coef_class_1: 0.9359 - dice_coef_class_2: 0.9878 - mean_iou: 0.9278 - val_loss: 0.0522 - val_categorical_accuracy: 0.9824 - val_dice_coefficient: 0.9653 - val_dice_coef_class_1: 0.9410 - val_dice_coef_class_2: 0.9895 - val_mean_iou: 0.9343
#
# Epoch 00033: val_loss did not improve from 0.04066
# Epoch 34/50
# 1099/1099 [==============================] - 43s 39ms/step - loss: 0.0547 - categorical_accuracy: 0.9805 - dice_coefficient: 0.9626 - dice_coef_class_1: 0.9371 - dice_coef_class_2: 0.9880 - mean_iou: 0.9291 - val_loss: 0.0482 - val_categorical_accuracy: 0.9835 - val_dice_coefficient: 0.9677 - val_dice_coef_class_1: 0.9453 - val_dice_coef_class_2: 0.9900 - val_mean_iou: 0.9384
#
# Epoch 00034: val_loss did not improve from 0.04066
# Epoch 00034: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(model.history.history['categorical_accuracy'])
plt.semilogy(model.history.history['val_categorical_accuracy'])
plt.title('model categorical_accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train_categorical_accuracy', 'val_categorical_accuracy'], loc='upper right');

# %%
model.load_weights('model-ResUpwellNet-0.h5')

# %%
# randindex=np.random.randint(0,len(sst_train))
randindex=1300
predictedSEGM=model.predict(np.reshape(sst_train[randindex,:,:],(1,input_size[0],input_size[1],1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(input_size[0],input_size[1]))

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(np.where(sst_train[randindex,:,:,0]==1, np.nan, sst_train[randindex,:,:,0]), cmap='jet')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SST');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Upwelling Segmentation');

plt.subplot(133)
plt.imshow(mask_train[randindex,:,:,0], cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');
