# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoSnoussi/Deep-UpwellRes-Net-a-convolutional-neural-network-for-Upwelling-detection-/blob/master/Upwell_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from tqdm import tqdm 

from keras import backend as K 
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, UpSampling2D, Dropout, Reshape, Conv2DTranspose, Add
from keras.layers import BatchNormalization, Activation 
from keras.models import Model, load_model 
from keras.optimizers import Adam 
from IPython.display import SVG 
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint, ReduceLROnPlateau 
from keras.utils import np_utils, plot_model
# Out:
# Using TensorFlow backend.

# %%
sst_path  = '/SST_train.npy'
mask_path = '/MASK_train.npy'

sst_train  = np.load(sst_path)
mask_train = np.load(mask_path)

mask_train = np.nan_to_num(mask_train, nan=1)
index = np.random.randint(sst_train.shape[0])

plt.figure(figsize=(15, 10))

plt.subplot(121)
plt.imshow(sst_train[index,:,:], cmap='jet')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.title('SST');

plt.subplot(122)
plt.imshow(mask_train[index,:,:], cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.title('Artificial Ground Truth');

# %%
sst_train = np.nan_to_num(sst_train, nan=1)

### Expand dims 
sst_train = np.expand_dims(sst_train, 3)
mask_train = np.expand_dims(mask_train, 3)

# %%
### Data Augumentation (Optional)
from keras.preprocessing.image import ImageDataGenerator 
datagen = ImageDataGenerator(rotation_range=90)
datagen.fit(sst_train)

for X_batch, y_batch in datagen.flow(sst_train, mask_train, batch_size=9):
	# create a grid of 3x3 images
	for i in range(0, 3):
		plt.subplot(330 + 1 + i)
		plt.imshow(X_batch[i].reshape(192, 192), cmap='jet')
		np.save('/Train_data/Data_Agum/'+'aug_{}.npy'.format(i), X_batch[i].reshape(192, 192))
	# show the plot
	plt.show()
	break

# %%
### One-Hot-Encoding 
mask_train_cat = np.reshape(mask_train[:,:,:,0], (1374,192*192))
mask_train_cat = np_utils.to_categorical(mask_train_cat, 2)
print(mask_train_cat.shape)
# Out:
# (1374, 36864, 2)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
input_size  = (192, 192, 1) 
def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True, num_classes=2):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    # Bottleneck 
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    output     = Conv2D(num_classes, (1,1), padding='valid')(c9)
    output     = Reshape((input_size[0]*input_size[1], num_classes))(output)
    output     = Activation('softmax')(output)
    model = Model(inputs=[input_img], outputs=[output])
    return model

# %% [markdown]
# # Calculate Weigths (Data Imbalance)

# %%
unique, counts = np.unique(mask_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 8085897, 1.0: 42565239}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.8403609940752366, 0.15963900592476346]

# %%
epsilon=0.00001  ## small constant add to numerator and denominator to avoid division by zero errors. 

### IoU coefficient 
def iou_class_1(y_true, y_pred):
  y_true_ = y_true[:,:,0]
  y_pred_ = y_pred[:,:,0]
  intersection = K.sum(y_true_ * y_pred_)
  union = (K.sum(y_true_) + K.sum(y_pred_)) - intersection
  iou = (intersection + epsilon) / (union + epsilon)
  return iou

def iou_class_2(y_true, y_pred):
  y_true_ = y_true[:,:,1]
  y_pred_ = y_pred[:,:,1]
  intersection = K.sum(y_true_ * y_pred_)
  union = (K.sum(y_true_) + K.sum(y_pred_)) - intersection
  iou = (intersection + epsilon) / (union + epsilon)
  return iou

def mean_iou(y_true, y_pred): 
  return ((iou_class_1(y_true, y_pred) + iou_class_2(y_true, y_pred)) / 2)


### Dice Coefficient 
def dice_coef_class_1(y_true, y_pred): 
  y_true_ = y_true[:,:,0]
  y_pred_ = y_pred[:,:,0]
  dice_numerator   = 2 * K.sum(y_true_ * y_pred_) + epsilon 
  dice_denominator = K.sum(y_true_) + K.sum(y_pred_) + epsilon 
  dice_coeff       = dice_numerator / dice_denominator 
  return dice_coeff 

def dice_coef_class_2(y_true, y_pred): 
  y_true_ = y_true[:,:,1]
  y_pred_ = y_pred[:,:,1]
  dice_numerator   = 2 * K.sum(y_true_ * y_pred_) + epsilon 
  dice_denominator = K.sum(y_true_) + K.sum(y_pred_) + epsilon 
  dice_coeff       = dice_numerator / dice_denominator
  return dice_coeff 

def dice_coefficient(y_true, y_pred): 
  return ((dice_coef_class_1(y_true, y_pred) + dice_coef_class_2(y_true, y_pred)) / 2) 

### Weighted Dice Loss 
def weighted_dice_coef(y_true, y_pred):
    return (0.84*dice_coef_class_1(y_true, y_pred) + 0.16*dice_coef_class_2(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_dice_coef(y_true, y_pred)

# %%
input_img = Input(input_size)
model = get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True)

model.compile(optimizer=Adam(), loss=dice_coef_loss, metrics=["categorical_accuracy", dice_coefficient, 
                                                              dice_coef_class_1, dice_coef_class_2, mean_iou])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 192, 192, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 192, 192, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 192, 192, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 192, 192, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 192, 192, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 192, 192, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 96, 96, 16)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 96, 96, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 96, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 96, 96, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 96, 96, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 96, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 96, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 48, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 48, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 48, 48, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 48, 48, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 48, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 48, 48, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 24, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 24, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 24, 24, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 24, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 24, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 24, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 12, 12, 128)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 12, 256)  295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 12, 12, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 12, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 12, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 24, 24, 128)  295040      activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 24, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 24, 24, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 24, 24, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 24, 24, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 24, 24, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 24, 24, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 24, 24, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 48, 48, 64)   73792       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 48, 48, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 48, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 48, 48, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 48, 48, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 48, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 48, 48, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 48, 48, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 96, 96, 32)   18464       activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 96, 96, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 96, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 96, 96, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 96, 96, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 96, 32)   9248        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 96, 96, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 96, 96, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 192, 192, 16) 4624        activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 192, 192, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 192, 192, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 192, 192, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 192, 192, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 192, 192, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 192, 192, 16) 2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 192, 192, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 192, 192, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 192, 192, 2)  34          activation_18[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 36864, 2)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 36864, 2)     0           reshape_1[0][0]
# ==================================================================================================
# Total params: 2,164,322
# Trainable params: 2,161,378
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model 
plot_model(model)

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.0001, verbose=1),
    ModelCheckpoint('/content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(sst_train, mask_train_cat, 
                    batch_size=16, 
                    epochs=50,
                    shuffle=True,
                    verbose=1,  
                    callbacks=callbacks, 
                    validation_split=0.2)
# Out:
# Train on 1099 samples, validate on 275 samples
# Epoch 1/50
# 1099/1099 [==============================] - 32s 29ms/step - loss: 0.4301 - categorical_accuracy: 0.8139 - dice_coefficient: 0.6646 - dice_coef_class_1: 0.5262 - dice_coef_class_2: 0.8030 - mean_iou: 0.5229 - val_loss: 0.5170 - val_categorical_accuracy: 0.6283 - val_dice_coefficient: 0.5700 - val_dice_coef_class_1: 0.4428 - val_dice_coef_class_2: 0.6972 - val_mean_iou: 0.4102
#
# Epoch 00001: val_loss improved from inf to 0.51696, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 2/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.2521 - categorical_accuracy: 0.9305 - dice_coefficient: 0.8221 - dice_coef_class_1: 0.7133 - dice_coef_class_2: 0.9308 - mean_iou: 0.7134 - val_loss: 0.6851 - val_categorical_accuracy: 0.3175 - val_dice_coefficient: 0.3142 - val_dice_coef_class_1: 0.3160 - val_dice_coef_class_2: 0.3123 - val_mean_iou: 0.1866
#
# Epoch 00002: val_loss did not improve from 0.51696
# Epoch 3/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1821 - categorical_accuracy: 0.9455 - dice_coefficient: 0.8742 - dice_coef_class_1: 0.7916 - dice_coef_class_2: 0.9568 - mean_iou: 0.7865 - val_loss: 0.3756 - val_categorical_accuracy: 0.7913 - val_dice_coefficient: 0.7158 - val_dice_coef_class_1: 0.5837 - val_dice_coef_class_2: 0.8480 - val_mean_iou: 0.5750
#
# Epoch 00003: val_loss improved from 0.51696 to 0.37561, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 4/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1540 - categorical_accuracy: 0.9500 - dice_coefficient: 0.8942 - dice_coef_class_1: 0.8234 - dice_coef_class_2: 0.9650 - mean_iou: 0.8163 - val_loss: 0.2010 - val_categorical_accuracy: 0.9268 - val_dice_coefficient: 0.8617 - val_dice_coef_class_1: 0.7717 - val_dice_coef_class_2: 0.9517 - val_mean_iou: 0.7690
#
# Epoch 00004: val_loss improved from 0.37561 to 0.20104, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 5/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1376 - categorical_accuracy: 0.9537 - dice_coefficient: 0.9057 - dice_coef_class_1: 0.8421 - dice_coef_class_2: 0.9693 - mean_iou: 0.8341 - val_loss: 0.2045 - val_categorical_accuracy: 0.9125 - val_dice_coefficient: 0.8589 - val_dice_coef_class_1: 0.7738 - val_dice_coef_class_2: 0.9441 - val_mean_iou: 0.7667
#
# Epoch 00005: val_loss did not improve from 0.20104
# Epoch 6/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1274 - categorical_accuracy: 0.9563 - dice_coefficient: 0.9128 - dice_coef_class_1: 0.8538 - dice_coef_class_2: 0.9718 - mean_iou: 0.8455 - val_loss: 0.1215 - val_categorical_accuracy: 0.9572 - val_dice_coefficient: 0.9181 - val_dice_coef_class_1: 0.8632 - val_dice_coef_class_2: 0.9731 - val_mean_iou: 0.8540
#
# Epoch 00006: val_loss improved from 0.20104 to 0.12150, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 7/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1225 - categorical_accuracy: 0.9573 - dice_coefficient: 0.9162 - dice_coef_class_1: 0.8593 - dice_coef_class_2: 0.9730 - mean_iou: 0.8507 - val_loss: 0.2966 - val_categorical_accuracy: 0.9195 - val_dice_coefficient: 0.8024 - val_dice_coef_class_1: 0.6520 - val_dice_coef_class_2: 0.9528 - val_mean_iou: 0.7061
#
# Epoch 00007: val_loss did not improve from 0.12150
# Epoch 8/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1178 - categorical_accuracy: 0.9584 - dice_coefficient: 0.9193 - dice_coef_class_1: 0.8646 - dice_coef_class_2: 0.9740 - mean_iou: 0.8557 - val_loss: 0.1193 - val_categorical_accuracy: 0.9614 - val_dice_coefficient: 0.9202 - val_dice_coef_class_1: 0.8637 - val_dice_coef_class_2: 0.9766 - val_mean_iou: 0.8578
#
# Epoch 00008: val_loss improved from 0.12150 to 0.11926, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 9/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1117 - categorical_accuracy: 0.9605 - dice_coefficient: 0.9237 - dice_coef_class_1: 0.8718 - dice_coef_class_2: 0.9755 - mean_iou: 0.8628 - val_loss: 0.0942 - val_categorical_accuracy: 0.9681 - val_dice_coefficient: 0.9367 - val_dice_coef_class_1: 0.8926 - val_dice_coef_class_2: 0.9808 - val_mean_iou: 0.8843
#
# Epoch 00009: val_loss improved from 0.11926 to 0.09425, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 10/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1138 - categorical_accuracy: 0.9597 - dice_coefficient: 0.9223 - dice_coef_class_1: 0.8694 - dice_coef_class_2: 0.9751 - mean_iou: 0.8606 - val_loss: 0.0957 - val_categorical_accuracy: 0.9646 - val_dice_coefficient: 0.9348 - val_dice_coef_class_1: 0.8913 - val_dice_coef_class_2: 0.9784 - val_mean_iou: 0.8810
#
# Epoch 00010: val_loss did not improve from 0.09425
# Epoch 11/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1024 - categorical_accuracy: 0.9636 - dice_coefficient: 0.9300 - dice_coef_class_1: 0.8823 - dice_coef_class_2: 0.9776 - mean_iou: 0.8731 - val_loss: 0.0924 - val_categorical_accuracy: 0.9674 - val_dice_coefficient: 0.9377 - val_dice_coef_class_1: 0.8950 - val_dice_coef_class_2: 0.9804 - val_mean_iou: 0.8859
#
# Epoch 00011: val_loss improved from 0.09425 to 0.09237, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 12/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.1021 - categorical_accuracy: 0.9636 - dice_coefficient: 0.9302 - dice_coef_class_1: 0.8828 - dice_coef_class_2: 0.9777 - mean_iou: 0.8737 - val_loss: 0.0815 - val_categorical_accuracy: 0.9695 - val_dice_coefficient: 0.9430 - val_dice_coef_class_1: 0.9053 - val_dice_coef_class_2: 0.9807 - val_mean_iou: 0.8951
#
# Epoch 00012: val_loss improved from 0.09237 to 0.08149, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 13/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0993 - categorical_accuracy: 0.9645 - dice_coefficient: 0.9322 - dice_coef_class_1: 0.8860 - dice_coef_class_2: 0.9783 - mean_iou: 0.8768 - val_loss: 0.0929 - val_categorical_accuracy: 0.9685 - val_dice_coefficient: 0.9380 - val_dice_coef_class_1: 0.8948 - val_dice_coef_class_2: 0.9812 - val_mean_iou: 0.8867
#
# Epoch 00013: val_loss did not improve from 0.08149
# Epoch 14/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0988 - categorical_accuracy: 0.9646 - dice_coefficient: 0.9325 - dice_coef_class_1: 0.8867 - dice_coef_class_2: 0.9784 - mean_iou: 0.8775 - val_loss: 0.0809 - val_categorical_accuracy: 0.9710 - val_dice_coefficient: 0.9451 - val_dice_coef_class_1: 0.9077 - val_dice_coef_class_2: 0.9824 - val_mean_iou: 0.8985
#
# Epoch 00014: val_loss improved from 0.08149 to 0.08086, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 15/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0967 - categorical_accuracy: 0.9654 - dice_coefficient: 0.9339 - dice_coef_class_1: 0.8889 - dice_coef_class_2: 0.9790 - mean_iou: 0.8796 - val_loss: 0.0792 - val_categorical_accuracy: 0.9711 - val_dice_coefficient: 0.9461 - val_dice_coef_class_1: 0.9098 - val_dice_coef_class_2: 0.9824 - val_mean_iou: 0.9002
#
# Epoch 00015: val_loss improved from 0.08086 to 0.07924, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 16/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0924 - categorical_accuracy: 0.9669 - dice_coefficient: 0.9369 - dice_coef_class_1: 0.8938 - dice_coef_class_2: 0.9799 - mean_iou: 0.8845 - val_loss: 0.0814 - val_categorical_accuracy: 0.9722 - val_dice_coefficient: 0.9453 - val_dice_coef_class_1: 0.9070 - val_dice_coef_class_2: 0.9835 - val_mean_iou: 0.8989
#
# Epoch 00016: val_loss did not improve from 0.07924
# Epoch 17/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0911 - categorical_accuracy: 0.9673 - dice_coefficient: 0.9376 - dice_coef_class_1: 0.8951 - dice_coef_class_2: 0.9801 - mean_iou: 0.8858 - val_loss: 0.1418 - val_categorical_accuracy: 0.9451 - val_dice_coefficient: 0.9024 - val_dice_coef_class_1: 0.8381 - val_dice_coef_class_2: 0.9667 - val_mean_iou: 0.8290
#
# Epoch 00017: val_loss did not improve from 0.07924
# Epoch 18/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0919 - categorical_accuracy: 0.9669 - dice_coefficient: 0.9372 - dice_coef_class_1: 0.8945 - dice_coef_class_2: 0.9799 - mean_iou: 0.8852 - val_loss: 0.0992 - val_categorical_accuracy: 0.9670 - val_dice_coefficient: 0.9334 - val_dice_coef_class_1: 0.8863 - val_dice_coef_class_2: 0.9805 - val_mean_iou: 0.8792
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00018: val_loss did not improve from 0.07924
# Epoch 19/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0825 - categorical_accuracy: 0.9705 - dice_coefficient: 0.9437 - dice_coef_class_1: 0.9053 - dice_coef_class_2: 0.9821 - mean_iou: 0.8962 - val_loss: 0.0663 - val_categorical_accuracy: 0.9772 - val_dice_coefficient: 0.9557 - val_dice_coef_class_1: 0.9249 - val_dice_coef_class_2: 0.9864 - val_mean_iou: 0.9171
#
# Epoch 00019: val_loss improved from 0.07924 to 0.06626, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 20/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0817 - categorical_accuracy: 0.9706 - dice_coefficient: 0.9441 - dice_coef_class_1: 0.9060 - dice_coef_class_2: 0.9822 - mean_iou: 0.8968 - val_loss: 0.0755 - val_categorical_accuracy: 0.9745 - val_dice_coefficient: 0.9498 - val_dice_coef_class_1: 0.9147 - val_dice_coef_class_2: 0.9850 - val_mean_iou: 0.9071
#
# Epoch 00020: val_loss did not improve from 0.06626
# Epoch 21/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0805 - categorical_accuracy: 0.9712 - dice_coefficient: 0.9450 - dice_coef_class_1: 0.9076 - dice_coef_class_2: 0.9825 - mean_iou: 0.8984 - val_loss: 0.0772 - val_categorical_accuracy: 0.9741 - val_dice_coefficient: 0.9489 - val_dice_coef_class_1: 0.9130 - val_dice_coef_class_2: 0.9848 - val_mean_iou: 0.9055
#
# Epoch 00021: val_loss did not improve from 0.06626
# Epoch 22/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0809 - categorical_accuracy: 0.9710 - dice_coefficient: 0.9448 - dice_coef_class_1: 0.9071 - dice_coef_class_2: 0.9824 - mean_iou: 0.8980 - val_loss: 0.0859 - val_categorical_accuracy: 0.9718 - val_dice_coefficient: 0.9436 - val_dice_coef_class_1: 0.9035 - val_dice_coef_class_2: 0.9837 - val_mean_iou: 0.8966
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00022: val_loss did not improve from 0.06626
# Epoch 23/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0803 - categorical_accuracy: 0.9712 - dice_coefficient: 0.9452 - dice_coef_class_1: 0.9079 - dice_coef_class_2: 0.9825 - mean_iou: 0.8987 - val_loss: 0.0659 - val_categorical_accuracy: 0.9776 - val_dice_coefficient: 0.9561 - val_dice_coef_class_1: 0.9255 - val_dice_coef_class_2: 0.9868 - val_mean_iou: 0.9179
#
# Epoch 00023: val_loss improved from 0.06626 to 0.06593, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 24/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0793 - categorical_accuracy: 0.9715 - dice_coefficient: 0.9458 - dice_coef_class_1: 0.9090 - dice_coef_class_2: 0.9827 - mean_iou: 0.8998 - val_loss: 0.0734 - val_categorical_accuracy: 0.9753 - val_dice_coefficient: 0.9510 - val_dice_coef_class_1: 0.9167 - val_dice_coef_class_2: 0.9854 - val_mean_iou: 0.9092
#
# Epoch 00024: val_loss did not improve from 0.06593
# Epoch 25/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0802 - categorical_accuracy: 0.9713 - dice_coefficient: 0.9451 - dice_coef_class_1: 0.9078 - dice_coef_class_2: 0.9825 - mean_iou: 0.8986 - val_loss: 0.0637 - val_categorical_accuracy: 0.9783 - val_dice_coefficient: 0.9575 - val_dice_coef_class_1: 0.9278 - val_dice_coef_class_2: 0.9871 - val_mean_iou: 0.9202
#
# Epoch 00025: val_loss improved from 0.06593 to 0.06371, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 26/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0790 - categorical_accuracy: 0.9718 - dice_coefficient: 0.9460 - dice_coef_class_1: 0.9092 - dice_coef_class_2: 0.9828 - mean_iou: 0.9002 - val_loss: 0.0699 - val_categorical_accuracy: 0.9763 - val_dice_coefficient: 0.9536 - val_dice_coef_class_1: 0.9211 - val_dice_coef_class_2: 0.9860 - val_mean_iou: 0.9135
#
# Epoch 00026: val_loss did not improve from 0.06371
# Epoch 27/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0787 - categorical_accuracy: 0.9717 - dice_coefficient: 0.9462 - dice_coef_class_1: 0.9096 - dice_coef_class_2: 0.9828 - mean_iou: 0.9005 - val_loss: 0.0725 - val_categorical_accuracy: 0.9757 - val_dice_coefficient: 0.9519 - val_dice_coef_class_1: 0.9181 - val_dice_coef_class_2: 0.9857 - val_mean_iou: 0.9107
#
# Epoch 00027: val_loss did not improve from 0.06371
# Epoch 28/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0784 - categorical_accuracy: 0.9719 - dice_coefficient: 0.9465 - dice_coef_class_1: 0.9100 - dice_coef_class_2: 0.9829 - mean_iou: 0.9009 - val_loss: 0.0642 - val_categorical_accuracy: 0.9778 - val_dice_coefficient: 0.9568 - val_dice_coef_class_1: 0.9269 - val_dice_coef_class_2: 0.9867 - val_mean_iou: 0.9191
#
# Epoch 00028: val_loss did not improve from 0.06371
# Epoch 29/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0784 - categorical_accuracy: 0.9719 - dice_coefficient: 0.9465 - dice_coef_class_1: 0.9100 - dice_coef_class_2: 0.9829 - mean_iou: 0.9009 - val_loss: 0.0632 - val_categorical_accuracy: 0.9784 - val_dice_coefficient: 0.9577 - val_dice_coef_class_1: 0.9283 - val_dice_coef_class_2: 0.9871 - val_mean_iou: 0.9206
#
# Epoch 00029: val_loss improved from 0.06371 to 0.06316, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 30/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0773 - categorical_accuracy: 0.9723 - dice_coefficient: 0.9472 - dice_coef_class_1: 0.9112 - dice_coef_class_2: 0.9832 - mean_iou: 0.9021 - val_loss: 0.0595 - val_categorical_accuracy: 0.9795 - val_dice_coefficient: 0.9601 - val_dice_coef_class_1: 0.9324 - val_dice_coef_class_2: 0.9877 - val_mean_iou: 0.9248
#
# Epoch 00030: val_loss improved from 0.06316 to 0.05946, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 31/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0783 - categorical_accuracy: 0.9719 - dice_coefficient: 0.9464 - dice_coef_class_1: 0.9099 - dice_coef_class_2: 0.9829 - mean_iou: 0.9008 - val_loss: 0.0787 - val_categorical_accuracy: 0.9740 - val_dice_coefficient: 0.9481 - val_dice_coef_class_1: 0.9113 - val_dice_coef_class_2: 0.9848 - val_mean_iou: 0.9043
#
# Epoch 00031: val_loss did not improve from 0.05946
# Epoch 32/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0773 - categorical_accuracy: 0.9722 - dice_coefficient: 0.9471 - dice_coef_class_1: 0.9110 - dice_coef_class_2: 0.9831 - mean_iou: 0.9019 - val_loss: 0.0584 - val_categorical_accuracy: 0.9798 - val_dice_coefficient: 0.9608 - val_dice_coef_class_1: 0.9337 - val_dice_coef_class_2: 0.9879 - val_mean_iou: 0.9261
#
# Epoch 00032: val_loss improved from 0.05946 to 0.05842, saving model to /content/drive/My Drive/Article_2/weigths/model-UupwellNet-0.h5
# Epoch 33/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0763 - categorical_accuracy: 0.9726 - dice_coefficient: 0.9478 - dice_coef_class_1: 0.9122 - dice_coef_class_2: 0.9834 - mean_iou: 0.9032 - val_loss: 0.0719 - val_categorical_accuracy: 0.9755 - val_dice_coefficient: 0.9518 - val_dice_coef_class_1: 0.9182 - val_dice_coef_class_2: 0.9854 - val_mean_iou: 0.9104
#
# Epoch 00033: val_loss did not improve from 0.05842
# Epoch 34/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0764 - categorical_accuracy: 0.9725 - dice_coefficient: 0.9478 - dice_coef_class_1: 0.9124 - dice_coef_class_2: 0.9833 - mean_iou: 0.9032 - val_loss: 0.0704 - val_categorical_accuracy: 0.9764 - val_dice_coefficient: 0.9534 - val_dice_coef_class_1: 0.9206 - val_dice_coef_class_2: 0.9862 - val_mean_iou: 0.9133
#
# Epoch 00034: val_loss did not improve from 0.05842
# Epoch 35/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0767 - categorical_accuracy: 0.9725 - dice_coefficient: 0.9476 - dice_coef_class_1: 0.9120 - dice_coef_class_2: 0.9833 - mean_iou: 0.9029 - val_loss: 0.0777 - val_categorical_accuracy: 0.9742 - val_dice_coefficient: 0.9487 - val_dice_coef_class_1: 0.9125 - val_dice_coef_class_2: 0.9849 - val_mean_iou: 0.9054
#
# Epoch 00035: val_loss did not improve from 0.05842
# Epoch 36/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0763 - categorical_accuracy: 0.9726 - dice_coefficient: 0.9479 - dice_coef_class_1: 0.9123 - dice_coef_class_2: 0.9834 - mean_iou: 0.9033 - val_loss: 0.0623 - val_categorical_accuracy: 0.9787 - val_dice_coefficient: 0.9584 - val_dice_coef_class_1: 0.9294 - val_dice_coef_class_2: 0.9874 - val_mean_iou: 0.9219
#
# Epoch 00036: val_loss did not improve from 0.05842
# Epoch 37/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0760 - categorical_accuracy: 0.9727 - dice_coefficient: 0.9480 - dice_coef_class_1: 0.9126 - dice_coef_class_2: 0.9834 - mean_iou: 0.9035 - val_loss: 0.0700 - val_categorical_accuracy: 0.9763 - val_dice_coefficient: 0.9534 - val_dice_coef_class_1: 0.9207 - val_dice_coef_class_2: 0.9860 - val_mean_iou: 0.9132
#
# Epoch 00037: val_loss did not improve from 0.05842
# Epoch 38/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0760 - categorical_accuracy: 0.9727 - dice_coefficient: 0.9480 - dice_coef_class_1: 0.9125 - dice_coef_class_2: 0.9834 - mean_iou: 0.9034 - val_loss: 0.0646 - val_categorical_accuracy: 0.9778 - val_dice_coefficient: 0.9566 - val_dice_coef_class_1: 0.9265 - val_dice_coef_class_2: 0.9867 - val_mean_iou: 0.9188
#
# Epoch 00038: val_loss did not improve from 0.05842
# Epoch 39/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0759 - categorical_accuracy: 0.9727 - dice_coefficient: 0.9481 - dice_coef_class_1: 0.9127 - dice_coef_class_2: 0.9834 - mean_iou: 0.9036 - val_loss: 0.0630 - val_categorical_accuracy: 0.9780 - val_dice_coefficient: 0.9575 - val_dice_coef_class_1: 0.9283 - val_dice_coef_class_2: 0.9868 - val_mean_iou: 0.9202
#
# Epoch 00039: val_loss did not improve from 0.05842
# Epoch 40/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0759 - categorical_accuracy: 0.9727 - dice_coefficient: 0.9480 - dice_coef_class_1: 0.9126 - dice_coef_class_2: 0.9835 - mean_iou: 0.9036 - val_loss: 0.0588 - val_categorical_accuracy: 0.9797 - val_dice_coefficient: 0.9606 - val_dice_coef_class_1: 0.9332 - val_dice_coef_class_2: 0.9879 - val_mean_iou: 0.9256
#
# Epoch 00040: val_loss did not improve from 0.05842
# Epoch 41/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0744 - categorical_accuracy: 0.9732 - dice_coefficient: 0.9491 - dice_coef_class_1: 0.9145 - dice_coef_class_2: 0.9837 - mean_iou: 0.9055 - val_loss: 0.0632 - val_categorical_accuracy: 0.9784 - val_dice_coefficient: 0.9580 - val_dice_coef_class_1: 0.9286 - val_dice_coef_class_2: 0.9873 - val_mean_iou: 0.9211
#
# Epoch 00041: val_loss did not improve from 0.05842
# Epoch 42/50
# 1099/1099 [==============================] - 20s 18ms/step - loss: 0.0749 - categorical_accuracy: 0.9730 - dice_coefficient: 0.9488 - dice_coef_class_1: 0.9140 - dice_coef_class_2: 0.9836 - mean_iou: 0.9050 - val_loss: 0.0664 - val_categorical_accuracy: 0.9775 - val_dice_coefficient: 0.9559 - val_dice_coef_class_1: 0.9250 - val_dice_coef_class_2: 0.9868 - val_mean_iou: 0.9176
#
# Epoch 00042: val_loss did not improve from 0.05842
# Epoch 00042: early stopping

# %%
model.load_weights('model-UupwellNet-0.h5')

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(model.history.history['categorical_accuracy'])
plt.semilogy(model.history.history['val_categorical_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');

# %%
randindex=np.random.randint(0,len(sst_train))
predictedSEGM=model.predict(np.reshape(sst_train[randindex,:,:],(1,input_size[0],input_size[1],1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(input_size[0],input_size[1]))

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(np.where(sst_train[randindex,:,:,0]==1, np.nan, sst_train[randindex,:,:,0]), cmap='jet')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SST');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Upwelling Segmentation');

plt.subplot(133)
plt.imshow(mask_train[randindex,:,:,0], cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');
