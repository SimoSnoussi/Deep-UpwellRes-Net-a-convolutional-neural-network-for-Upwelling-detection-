# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoSnoussi/UpwellNet-/blob/master/BCE_UNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from tqdm import tqdm 

from keras import backend as K 
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, UpSampling2D, Dropout, Reshape, Conv2DTranspose, Add
from keras.layers import BatchNormalization, Activation 
from keras.models import Model, load_model 
from keras.optimizers import Adam 
from IPython.display import SVG 
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint, ReduceLROnPlateau 
from keras.utils import np_utils, plot_model
# Out:
# Using TensorFlow backend.

# %%
sst_path  = '/content/drive/My Drive/Article_2/Train_data/SST_train.npy'
mask_path = '/content/drive/My Drive/Article_2/Train_data/MASK_train.npy'

sst_train  = np.load(sst_path)
mask_train = np.load(mask_path)


index = np.random.randint(sst_train.shape[0])


plt.figure(figsize=(15, 10))

plt.subplot(121)
plt.imshow(sst_train[index,:,:], cmap='jet')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.title('SST');

plt.subplot(122)
plt.imshow(mask_train[index,:,:], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.title('Artificial Ground Truth');

# %%
mask_train = np.nan_to_num(mask_train, nan=1)
sst_train = np.nan_to_num(sst_train, nan=1)

### Expand dims 
sst_train = np.expand_dims(sst_train, 3)
mask_train = np.expand_dims(mask_train, 3)

### One-Hot-Encoding 
mask_train_cat = np.reshape(mask_train[:,:,:,0], (1374,192*192))
mask_train_cat = np_utils.to_categorical(mask_train_cat, 2)
print(mask_train_cat.shape)
# Out:
# (1374, 36864, 2)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
input_size  = (192, 192, 1) 
def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True, num_classes=2):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    # Bottleneck 
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    output     = Conv2D(num_classes, (1,1), padding='valid')(c9)
    output     = Reshape((input_size[0]*input_size[1], num_classes))(output)
    output     = Activation('softmax')(output)
    model = Model(inputs=[input_img], outputs=[output])
    return model

# %% [markdown]
# # Calculate Weigths (Data Imbalance)

# %%
unique, counts = np.unique(mask_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 8085897, 1.0: 42565239}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.8403609940752366, 0.15963900592476346]

# %%
epsilon=0.00001  ## small constant add to numerator and denominator to avoid division by zero errors. 

### IoU coefficient 
def iou_class_1(y_true, y_pred):
  y_true_ = y_true[:,:,0]
  y_pred_ = y_pred[:,:,0]
  intersection = K.sum(y_true_ * y_pred_)
  union = (K.sum(y_true_) + K.sum(y_pred_)) - intersection
  iou = (intersection + epsilon) / (union + epsilon)
  return iou

def iou_class_2(y_true, y_pred):
  y_true_ = y_true[:,:,1]
  y_pred_ = y_pred[:,:,1]
  intersection = K.sum(y_true_ * y_pred_)
  union = (K.sum(y_true_) + K.sum(y_pred_)) - intersection
  iou = (intersection + epsilon) / (union + epsilon)
  return iou

def mean_iou(y_true, y_pred): 
  return ((iou_class_1(y_true, y_pred) + iou_class_2(y_true, y_pred)) / 2)


### Dice Coefficient 
def dice_coef_class_1(y_true, y_pred): 
  y_true_ = y_true[:,:,0]
  y_pred_ = y_pred[:,:,0]
  dice_numerator   = 2 * K.sum(y_true_ * y_pred_) + epsilon 
  dice_denominator = K.sum(y_true_) + K.sum(y_pred_) + epsilon 
  dice_coeff       = dice_numerator / dice_denominator 
  return dice_coeff 

def dice_coef_class_2(y_true, y_pred): 
  y_true_ = y_true[:,:,1]
  y_pred_ = y_pred[:,:,1]
  dice_numerator   = 2 * K.sum(y_true_ * y_pred_) + epsilon 
  dice_denominator = K.sum(y_true_) + K.sum(y_pred_) + epsilon 
  dice_coeff       = dice_numerator / dice_denominator
  return dice_coeff 

def dice_coefficient(y_true, y_pred): 
  return ((dice_coef_class_1(y_true, y_pred) + dice_coef_class_2(y_true, y_pred)) / 2) 

### Weighted Dice Loss 
def weighted_dice_coef(y_true, y_pred):
    return (0.84*dice_coef_class_1(y_true, y_pred) + 0.16*dice_coef_class_2(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_dice_coef(y_true, y_pred)

# %%
input_img = Input(input_size)
model = get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True)

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=["categorical_accuracy", dice_coefficient, 
                                                              dice_coef_class_1, dice_coef_class_2, mean_iou])
# model.summary()

# %%
# from keras.utils import plot_model 
# plot_model(model)

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.0001, verbose=1),
    ModelCheckpoint('/content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(sst_train, mask_train_cat, 
                    batch_size=16, 
                    epochs=50,
                    shuffle=True,
                    verbose=1,  
                    callbacks=callbacks, 
                    validation_split=0.2)
# Out:
# Train on 1099 samples, validate on 275 samples
# Epoch 1/50
# 1099/1099 [==============================] - 23s 21ms/step - loss: 0.2445 - categorical_accuracy: 0.9132 - dice_coefficient: 0.7382 - dice_coef_class_1: 0.5831 - dice_coef_class_2: 0.8933 - mean_iou: 0.6162 - val_loss: 11.8769 - val_categorical_accuracy: 0.2106 - val_dice_coefficient: 0.2002 - val_dice_coef_class_1: 0.2861 - val_dice_coef_class_2: 0.1143 - val_mean_iou: 0.1139
#
# Epoch 00001: val_loss improved from inf to 11.87689, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 2/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.1452 - categorical_accuracy: 0.9459 - dice_coefficient: 0.8328 - dice_coef_class_1: 0.7216 - dice_coef_class_2: 0.9440 - mean_iou: 0.7295 - val_loss: 9.1426 - val_categorical_accuracy: 0.3179 - val_dice_coefficient: 0.3162 - val_dice_coef_class_1: 0.3164 - val_dice_coef_class_2: 0.3159 - val_mean_iou: 0.1881
#
# Epoch 00002: val_loss improved from 11.87689 to 9.14258, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 3/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.1253 - categorical_accuracy: 0.9520 - dice_coefficient: 0.8563 - dice_coef_class_1: 0.7597 - dice_coef_class_2: 0.9529 - mean_iou: 0.7615 - val_loss: 0.5945 - val_categorical_accuracy: 0.8149 - val_dice_coefficient: 0.7444 - val_dice_coef_class_1: 0.6161 - val_dice_coef_class_2: 0.8727 - val_mean_iou: 0.6102
#
# Epoch 00003: val_loss improved from 9.14258 to 0.59455, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 4/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.1147 - categorical_accuracy: 0.9552 - dice_coefficient: 0.8683 - dice_coef_class_1: 0.7793 - dice_coef_class_2: 0.9572 - mean_iou: 0.7784 - val_loss: 0.1285 - val_categorical_accuracy: 0.9498 - val_dice_coefficient: 0.8820 - val_dice_coef_class_1: 0.8044 - val_dice_coef_class_2: 0.9597 - val_mean_iou: 0.7982
#
# Epoch 00004: val_loss improved from 0.59455 to 0.12853, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 5/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.1089 - categorical_accuracy: 0.9570 - dice_coefficient: 0.8773 - dice_coef_class_1: 0.7943 - dice_coef_class_2: 0.9604 - mean_iou: 0.7915 - val_loss: 0.2999 - val_categorical_accuracy: 0.8982 - val_dice_coefficient: 0.8250 - val_dice_coef_class_1: 0.7240 - val_dice_coef_class_2: 0.9261 - val_mean_iou: 0.7190
#
# Epoch 00005: val_loss did not improve from 0.12853
# Epoch 6/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.1016 - categorical_accuracy: 0.9595 - dice_coefficient: 0.8834 - dice_coef_class_1: 0.8044 - dice_coef_class_2: 0.9624 - mean_iou: 0.8004 - val_loss: 0.1236 - val_categorical_accuracy: 0.9546 - val_dice_coefficient: 0.8805 - val_dice_coef_class_1: 0.7955 - val_dice_coef_class_2: 0.9655 - val_mean_iou: 0.7990
#
# Epoch 00006: val_loss improved from 0.12853 to 0.12365, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 7/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0953 - categorical_accuracy: 0.9618 - dice_coefficient: 0.8911 - dice_coef_class_1: 0.8173 - dice_coef_class_2: 0.9649 - mean_iou: 0.8118 - val_loss: 0.0870 - val_categorical_accuracy: 0.9645 - val_dice_coefficient: 0.8993 - val_dice_coef_class_1: 0.8295 - val_dice_coef_class_2: 0.9692 - val_mean_iou: 0.8249
#
# Epoch 00007: val_loss improved from 0.12365 to 0.08704, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 8/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0946 - categorical_accuracy: 0.9616 - dice_coefficient: 0.8924 - dice_coef_class_1: 0.8193 - dice_coef_class_2: 0.9655 - mean_iou: 0.8137 - val_loss: 0.1346 - val_categorical_accuracy: 0.9482 - val_dice_coefficient: 0.8738 - val_dice_coef_class_1: 0.7819 - val_dice_coef_class_2: 0.9656 - val_mean_iou: 0.7899
#
# Epoch 00008: val_loss did not improve from 0.08704
# Epoch 9/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0875 - categorical_accuracy: 0.9645 - dice_coefficient: 0.9010 - dice_coef_class_1: 0.8338 - dice_coef_class_2: 0.9682 - mean_iou: 0.8268 - val_loss: 0.2290 - val_categorical_accuracy: 0.9233 - val_dice_coefficient: 0.8233 - val_dice_coef_class_1: 0.6959 - val_dice_coef_class_2: 0.9507 - val_mean_iou: 0.7259
#
# Epoch 00009: val_loss did not improve from 0.08704
# Epoch 10/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0888 - categorical_accuracy: 0.9640 - dice_coefficient: 0.8998 - dice_coef_class_1: 0.8318 - dice_coef_class_2: 0.9678 - mean_iou: 0.8251 - val_loss: 0.0697 - val_categorical_accuracy: 0.9731 - val_dice_coefficient: 0.9252 - val_dice_coef_class_1: 0.8737 - val_dice_coef_class_2: 0.9766 - val_mean_iou: 0.8652
#
# Epoch 00010: val_loss improved from 0.08704 to 0.06966, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 11/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0885 - categorical_accuracy: 0.9639 - dice_coefficient: 0.9005 - dice_coef_class_1: 0.8329 - dice_coef_class_2: 0.9681 - mean_iou: 0.8261 - val_loss: 0.0805 - val_categorical_accuracy: 0.9696 - val_dice_coefficient: 0.9263 - val_dice_coef_class_1: 0.8748 - val_dice_coef_class_2: 0.9778 - val_mean_iou: 0.8673
#
# Epoch 00011: val_loss did not improve from 0.06966
# Epoch 12/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0837 - categorical_accuracy: 0.9656 - dice_coefficient: 0.9050 - dice_coef_class_1: 0.8404 - dice_coef_class_2: 0.9695 - mean_iou: 0.8330 - val_loss: 0.1252 - val_categorical_accuracy: 0.9572 - val_dice_coefficient: 0.8982 - val_dice_coef_class_1: 0.8260 - val_dice_coef_class_2: 0.9704 - val_mean_iou: 0.8242
#
# Epoch 00012: val_loss did not improve from 0.06966
# Epoch 13/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0813 - categorical_accuracy: 0.9664 - dice_coefficient: 0.9081 - dice_coef_class_1: 0.8456 - dice_coef_class_2: 0.9706 - mean_iou: 0.8378 - val_loss: 0.0655 - val_categorical_accuracy: 0.9734 - val_dice_coefficient: 0.9287 - val_dice_coef_class_1: 0.8792 - val_dice_coef_class_2: 0.9781 - val_mean_iou: 0.8710
#
# Epoch 00013: val_loss improved from 0.06966 to 0.06548, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 14/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0809 - categorical_accuracy: 0.9664 - dice_coefficient: 0.9081 - dice_coef_class_1: 0.8457 - dice_coef_class_2: 0.9705 - mean_iou: 0.8378 - val_loss: 0.1189 - val_categorical_accuracy: 0.9564 - val_dice_coefficient: 0.9008 - val_dice_coef_class_1: 0.8299 - val_dice_coef_class_2: 0.9718 - val_mean_iou: 0.8279
#
# Epoch 00014: val_loss did not improve from 0.06548
# Epoch 15/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0795 - categorical_accuracy: 0.9672 - dice_coefficient: 0.9105 - dice_coef_class_1: 0.8496 - dice_coef_class_2: 0.9714 - mean_iou: 0.8416 - val_loss: 0.0856 - val_categorical_accuracy: 0.9637 - val_dice_coefficient: 0.9115 - val_dice_coef_class_1: 0.8489 - val_dice_coef_class_2: 0.9742 - val_mean_iou: 0.8451
#
# Epoch 00015: val_loss did not improve from 0.06548
# Epoch 16/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0795 - categorical_accuracy: 0.9672 - dice_coefficient: 0.9104 - dice_coef_class_1: 0.8496 - dice_coef_class_2: 0.9713 - mean_iou: 0.8415 - val_loss: 0.0798 - val_categorical_accuracy: 0.9641 - val_dice_coefficient: 0.9110 - val_dice_coef_class_1: 0.8486 - val_dice_coef_class_2: 0.9734 - val_mean_iou: 0.8429
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00016: val_loss did not improve from 0.06548
# Epoch 17/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0733 - categorical_accuracy: 0.9699 - dice_coefficient: 0.9163 - dice_coef_class_1: 0.8595 - dice_coef_class_2: 0.9731 - mean_iou: 0.8507 - val_loss: 0.0534 - val_categorical_accuracy: 0.9774 - val_dice_coefficient: 0.9350 - val_dice_coef_class_1: 0.8899 - val_dice_coef_class_2: 0.9801 - val_mean_iou: 0.8815
#
# Epoch 00017: val_loss improved from 0.06548 to 0.05336, saving model to /content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5
# Epoch 18/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0696 - categorical_accuracy: 0.9714 - dice_coefficient: 0.9198 - dice_coef_class_1: 0.8654 - dice_coef_class_2: 0.9743 - mean_iou: 0.8564 - val_loss: 0.0573 - val_categorical_accuracy: 0.9760 - val_dice_coefficient: 0.9334 - val_dice_coef_class_1: 0.8871 - val_dice_coef_class_2: 0.9797 - val_mean_iou: 0.8789
#
# Epoch 00018: val_loss did not improve from 0.05336
# Epoch 19/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0693 - categorical_accuracy: 0.9713 - dice_coefficient: 0.9202 - dice_coef_class_1: 0.8659 - dice_coef_class_2: 0.9745 - mean_iou: 0.8570 - val_loss: 0.0635 - val_categorical_accuracy: 0.9726 - val_dice_coefficient: 0.9303 - val_dice_coef_class_1: 0.8812 - val_dice_coef_class_2: 0.9793 - val_mean_iou: 0.8738
#
# Epoch 00019: val_loss did not improve from 0.05336
# Epoch 20/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0689 - categorical_accuracy: 0.9715 - dice_coefficient: 0.9211 - dice_coef_class_1: 0.8675 - dice_coef_class_2: 0.9747 - mean_iou: 0.8584 - val_loss: 0.0695 - val_categorical_accuracy: 0.9698 - val_dice_coefficient: 0.9251 - val_dice_coef_class_1: 0.8721 - val_dice_coef_class_2: 0.9782 - val_mean_iou: 0.8656
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00020: val_loss did not improve from 0.05336
# Epoch 21/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0684 - categorical_accuracy: 0.9719 - dice_coefficient: 0.9219 - dice_coef_class_1: 0.8688 - dice_coef_class_2: 0.9750 - mean_iou: 0.8598 - val_loss: 0.0623 - val_categorical_accuracy: 0.9744 - val_dice_coefficient: 0.9326 - val_dice_coef_class_1: 0.8854 - val_dice_coef_class_2: 0.9798 - val_mean_iou: 0.8777
#
# Epoch 00021: val_loss did not improve from 0.05336
# Epoch 22/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0684 - categorical_accuracy: 0.9718 - dice_coefficient: 0.9217 - dice_coef_class_1: 0.8685 - dice_coef_class_2: 0.9749 - mean_iou: 0.8595 - val_loss: 0.0663 - val_categorical_accuracy: 0.9724 - val_dice_coefficient: 0.9299 - val_dice_coef_class_1: 0.8804 - val_dice_coef_class_2: 0.9793 - val_mean_iou: 0.8733
#
# Epoch 00022: val_loss did not improve from 0.05336
# Epoch 23/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0691 - categorical_accuracy: 0.9715 - dice_coefficient: 0.9212 - dice_coef_class_1: 0.8677 - dice_coef_class_2: 0.9747 - mean_iou: 0.8587 - val_loss: 0.0655 - val_categorical_accuracy: 0.9718 - val_dice_coefficient: 0.9287 - val_dice_coef_class_1: 0.8783 - val_dice_coef_class_2: 0.9790 - val_mean_iou: 0.8714
#
# Epoch 00023: val_loss did not improve from 0.05336
# Epoch 24/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0678 - categorical_accuracy: 0.9720 - dice_coefficient: 0.9224 - dice_coef_class_1: 0.8696 - dice_coef_class_2: 0.9751 - mean_iou: 0.8605 - val_loss: 0.0646 - val_categorical_accuracy: 0.9735 - val_dice_coefficient: 0.9320 - val_dice_coef_class_1: 0.8842 - val_dice_coef_class_2: 0.9798 - val_mean_iou: 0.8768
#
# Epoch 00024: val_loss did not improve from 0.05336
# Epoch 25/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0669 - categorical_accuracy: 0.9722 - dice_coefficient: 0.9236 - dice_coef_class_1: 0.8717 - dice_coef_class_2: 0.9755 - mean_iou: 0.8625 - val_loss: 0.0759 - val_categorical_accuracy: 0.9679 - val_dice_coefficient: 0.9230 - val_dice_coef_class_1: 0.8682 - val_dice_coef_class_2: 0.9778 - val_mean_iou: 0.8622
#
# Epoch 00025: val_loss did not improve from 0.05336
# Epoch 26/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0667 - categorical_accuracy: 0.9725 - dice_coefficient: 0.9237 - dice_coef_class_1: 0.8719 - dice_coef_class_2: 0.9755 - mean_iou: 0.8627 - val_loss: 0.0715 - val_categorical_accuracy: 0.9712 - val_dice_coefficient: 0.9284 - val_dice_coef_class_1: 0.8779 - val_dice_coef_class_2: 0.9789 - val_mean_iou: 0.8711
#
# Epoch 00026: val_loss did not improve from 0.05336
# Epoch 27/50
# 1099/1099 [==============================] - 9s 8ms/step - loss: 0.0660 - categorical_accuracy: 0.9726 - dice_coefficient: 0.9244 - dice_coef_class_1: 0.8730 - dice_coef_class_2: 0.9758 - mean_iou: 0.8638 - val_loss: 0.0666 - val_categorical_accuracy: 0.9724 - val_dice_coefficient: 0.9314 - val_dice_coef_class_1: 0.8829 - val_dice_coef_class_2: 0.9798 - val_mean_iou: 0.8758
#
# Epoch 00027: val_loss did not improve from 0.05336
# Epoch 00027: early stopping

# %%
model.load_weights('/content/drive/My Drive/Article_2/weigths/model-BCE_UupwellNet-0.h5')

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(model.history.history['categorical_accuracy'])
plt.semilogy(model.history.history['val_categorical_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');

# %%
randindex=np.random.randint(0,len(sst_train))
predictedSEGM=model.predict(np.reshape(sst_train[randindex,:,:],(1,input_size[0],input_size[1],1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(input_size[0],input_size[1]))

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(np.where(sst_train[randindex,:,:,0]==1, np.nan, sst_train[randindex,:,:,0]), cmap='jet')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SST');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Upwelling Segmentation');

plt.subplot(133)
plt.imshow(mask_train[randindex,:,:,0], cmap='binary')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

# %%
from skimage import morphology 
from scipy import ndimage 

### Like region growing to remove offshore noise 
def like_region_growing(label): 
    a = label > 0 
    b = morphology.remove_small_holes(a)
    c = b.astype(int)
    c = np.where(c==0,1, 0)
    d = ndimage.binary_fill_holes(c)
    e = np.where(d==1, 0, 1)
    return e 

label = like_region_growing(predictedSEGMimage)
label2 = like_region_growing(mask_train[randindex,:,:,0])

fig, (ax0,ax1) = plt.subplots(1, 2, figsize=(15,10))
ax0.imshow(label, cmap='binary')
ax1.imshow(label2, cmap='binary')
